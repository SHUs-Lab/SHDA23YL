# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sample_data = np.load("whole_data.npy")[np.where(np.load("whole_label.npy")==1)[0][101]]
for ch in range(sample_data.shape[-1]):
    plt.imshow(sample_data[:,:,ch], cmap="Greys")
    plt.axis("off")
    plt.show()
# Out:
# (100, 100, 7)

# %%
for ch in range(sample_data.shape[-1]):
    plt.imshow(sample_data[:,:,ch], cmap="Greys")
    plt.axis("off")
    plt.show()
